# %%
from G_Brownian_Motion.Geometric_BM import geometricBrownianMotion
from G_Brownian_Motion.plots import plot_benchmarks_gpu_cpu_MC

# %%
from matplotlib import pyplot as plt

gBMSim = geometricBrownianMotion(100, 0.2, 0.1, 30, 1.0, 365)
plt.plot(gBMSim)
plt.xlabel("Time (Days)")
plt.ylabel("Price ($)")
plt.title(r'Geometric Brownian Motion with 75 paths, with $\sigma = 0.1$ and $\mu$=0.2')
#matplot2tikz.save("GBM.tex") uncomment for saving.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       6 plt.ylabel("Price ($)")
#       7 plt.title(r'Geometric Brownian Motion with 75 paths, with $\sigma = 0.1$ and $\mu$=0.2')
# ----> 8 matplot2tikz.save("GBM.tex")
#       9 plt.show()
#
# NameError: name 'matplot2tikz' is not defined

# %%
plot_benchmarks_gpu_cpu_MC()
# Out:
# C:\Users\jayma\Desktop\Projects\Personal\finalYearProject\G_Brownian_Motion\plots.py:94: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
